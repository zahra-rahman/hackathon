# %%
#Cher's Closet by Zahra 12CRA: 
import pandas as pd
import random

weather = {
    'date' : ['23' , '24', '25' ,'26' , '27' ,'28', '29'], 
    'temperature' : [-1, 4, 8, 15, 20, 26 , 35],
    'weather' : ['snow', 'heavy rain', 'cloudy', 'light showers', 'clear sky', 'very hot', 'very very hot']
}
df = pd.DataFrame(weather, columns = ['date', 'temperature', 'weather'])
pd.DataFrame.reset_index(df, drop=True, inplace= True)


girls = ['Cher', 'Dion', 'Tai']
tops = ['red shirt', 'pink top', 'yellow vest']
bottoms = ['mom jeans', 'black skirt', 'pink cargos']
randtop = random.choice(tops)
randbot = random.choice(bottoms)

name = input("Hi! What's your name?")

if name in girls:
    date = input("what's the date")
    if int(date) >= 23 and int(date) <= 29 :
        print("this is the temperature for the week")
        print(df) 
        print("this is todays outfit:")
        print(str(randtop) + " + " + str(randbot) )    
else:
    print("unauthorised")
# Out:
# this is the temperature for the week
#   date  temperature        weather
# 0   23           -1           snow
# 1   24            4     heavy rain
# 2   25            8         cloudy
# 3   26           15  light showers
# 4   27           20      clear sky
# 5   28           26       very hot
# 6   29           35  very very hot
# this is todays outfit:
# pink topmom jeans

# %%
#import tkinter to see whos clothes it is
from tkinter import *
import tkinter as tk
import webbrowser
import pandas as pd
import numpy as np 

link1 = "https://zahra-rahman.github.io/hackathon/"





#weather data frame
weather = {
    'date' : [23 , 24, 25 ,26 , 27 ,28, 29], 
    'temperature' : [-1, 4, 8, 15, 20, 26 , 35],
    'weather' : ['snow', 'heavy rain', 'cloudy', 'light showers', 'clear sky', 'very hot', 'very very hot']
}
df = pd.DataFrame(weather, columns = ['date', 'temperature', 'weather'])



#if its Cher, take to her window;
def printData(firstName, Date):
    if firstName == 'Cher' and Date == '23':
        top = Toplevel()
        top.geometry('200x300')
        top.configure(bg='#f8edeb')
        label5 = Label(top,text = df.iloc[[0]], font = 40, bg="#f8edeb")
        label5.pack()
        def main():
            #mainWindow = tk.Tk()
            button = tk.Button(top, text = "Today's Look!", command= lambda: webbrowser.open(link1))
            button.pack()
            mainWindow.mainloop()
        main()

    elif firstName == 'Cher' and Date == '23':
        top = Toplevel()
        top.geometry('200x300')
        top.configure(bg='#f8edeb')
        label5 = Label(top,text = df.iloc[0], font = 40, bg="#f8edeb")
        label5.pack()
        def main():
            #mainWindow = tk.Tk()
            button = tk.Button(top, text = "Today's Look!", command= lambda: webbrowser.open(link2))
            button.pack()
            mainWindow.mainloop()
        main()
    else: 
        print('bye')
    #print(lastName)
        root.destroy()

#input from entries
def get_input():

    firstName = entry1.get()
    Date = entry2.get()
    printData(firstName, Date)

#main window form
root = Tk(className='python')
root.configure(bg="white")
#Label 1
label1 = Label(root,text = 'First Name', bg='white', font = 40)
label1.pack()
label1.config(justify = CENTER)

entry1 = Entry(root,bg='#FCD5CE', font=40 )
entry1.pack()

label3 = Label(root, text="Date",  bg='white', font=40)
label3.pack()
label1.config(justify = CENTER)

entry2 = Entry(root, width = 30, bg='#FCD5CE', font=40)
entry2.pack()

button1 = Button(root, text = 'submit', bg ='white', font=40)
button1.pack() 
button1.config(command = get_input)

root.mainloop()
